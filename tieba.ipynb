# %%
import requests
from lxml import etree
import ast
import json
import pymysql as msql


class TiebaSpider:
    def __init__(self, name):
        self.flag = 0
        self.name = name
        self.url_temp = "https://tieba.baidu.com/f?kw=" + name + "&ie=utf-8&pn={}"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"
        }

    def start_url(self):     # 1. url
        for i in range(0,20):
            start_url = self.url_temp.format(i)
            return start_url

    def parse_url(self, url):   # 2. 发送请求 获取响应
        response = requests.get(url, self.headers)
        html_str = response.content.decode()
        return html_str

    def get_content_list(self, html_str):   # 3.提取数据
        html = etree.HTML(html_str)
        li_str = "//li[@class=' j_thread_list clearfix']" if self.flag !=0 else "//li[@class=' j_thread_list thread_top j_thread_list clearfix']"
        li_list = html.xpath(li_str)
        content_list = []
        for li in li_list:
            # xpath-> 字典
            data = str(li.xpath('./@data-field')[0]) + ''
            data = data.replace('null','None')
            data = data.replace('true', 'True')
            data = ast.literal_eval(data)
            item = {}
            item['id'] = data['id']
            item['user'] = data['author_nickname'] if data['author_nickname'] !=None else data['author_name']
            item['renum'] = data['reply_num']
            item['is_top'] = 'False' if data['is_top'] == None else 'True'
            item['is_good'] = 'False' if data['is_good'] == None else 'True'
            item['title'] = str(li.xpath("./div/div[2]/div[1]/div[1]/a/text()")[0]) + ''
            content_list.append(item)
            


        # 第一页的直接返回即可
        if self.flag == 0:
            return content_list
        # 提取下一页url地址
        next_url = "https:" + html.xpath("//a[@class='next pagination-item ']/@href")[0] if len(html.xpath("//a[@class='next pagination-item ']/@href")) > 0 else None
        return content_list, next_url

#     def save_html_str(self, content_list):   # 4. 保存
#         with open('tieba.json', 'w') as f:
#             json.dump(content_list, f)
    
    def create(self):
        conn = msql.connect("localhost", "root", "1234", "test")#连接数据库 
     
        cursor = conn.cursor()
        cursor.execute("DROP TABLE IF EXISTS Information") #删除掉已有的EMPLOYER表
    
        sql = """CREATE TABLE Information (
                ID BIGINT PRIMARY KEY,
                USER  CHAR(255),
                RENUM INT(20),
                IS_TOP CHAR(255),
                IS_GOOD CHAR(255),
                TITLE LONGTEXT)"""
     
        cursor.execute(sql)
        conn.close()
        
    def insert(self,value):
        conn = msql.connect("localhost", "root", "1234", "test")
 
        cursor = conn.cursor()
        sql = "INSERT INTO Information(ID,USER,RENUM,IS_TOP,IS_GOOD,TITLE) VALUES (%s, %s,  %s,%s,%s,%s)"
        try:
            cursor.execute(sql,value)
            conn.commit()
            print('插入数据成功')
        except:
            conn.rollback()
            print("插入数据失败")
        conn.close()       

    def run(self):
        next_url = self.start_url()
        self.create()
        while next_url is not None:
            # 2. 发送请求 获取响应
            html_str = self.parse_url(next_url)
            # 3. 提取数据
            if self.flag == 0:
                con = self.get_content_list(html_str)
                self.flag = 1

            content_list, next_url = self.get_content_list(html_str)
            content_list.extend(con)
                        
            print(content_list,'\n')

            for content in content_list:
                l=[]
                for key ,values in content.items():
                    l.append(values)
                self.insert(l)
            

#             # 4. 保存
#             self.save_html_str(content_list)
  
            
            
if __name__ == "__main__":
    tieba = TiebaSpider("新型")
    tieba.run()
# Out:
# [{'id': 6828933694, 'user': '贴吧用户_a6QbD4a', 'renum': 9, 'is_top': 'False', 'is_good': 'False', 'title': '作品版权！软件著作权申请！有需要加我微 包下证！同行最低价！'}, {'id': 6838334364, 'user': '工艺管道87', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '晋宁玻璃钢工艺管道直供'}, {'id': 6813063297, 'user': '戏子说尽悲欢', 'renum': 1, 'is_top': 'False', 'is_good': 'False', 'title': 'SW专利撰写，寻长期合作，V18888175981'}, {'id': 6812956399, 'user': '工艺管道87', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '汉川供应玻璃钢风管'}, {'id': 6765130137, 'user': 'Dream_obtain', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '《跳动的心》'}, {'id': 6726726708, 'user': '工艺管道87', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '荣成电力电缆管道13722982051'}, {'id': 6714519065, 'user': 'The_same09', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '【招聘】工业漆研发总工'}, {'id': 6703991408, 'user': '工艺管道87', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '三门峡电缆穿线管材质'}, {'id': 6698030489, 'user': '工艺管道87', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '涟源工艺管道安装'}, {'id': 6676117513, 'user': '戏子说尽悲欢', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '专业撰写专利'}, {'id': 6663875082, 'user': '光怪0陆离', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '华润水泥（上思）有限公司'}, {'id': 6661193332, 'user': '光怪0陆离', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '华润水泥（上思）有限公司'}, {'id': 6659021064, 'user': '光怪0陆离', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '华润水泥（上思）有限公司'}, {'id': 6652518487, 'user': '光怪0陆离', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '华润水泥（上思）有限公司'}, {'id': 6632857973, 'user': '光怪0陆离', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '江苏久诺建筑装饰工程有限公司青岛分公司'}, {'id': 6473304487, 'user': '中公教育小泡芙', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '2019茂名公务员面试名单确定方式，面试名单怎么看？'}, {'id': 5566628485, 'user': '爱互吧', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '商塑企业让零售数据更有情感！'}, {'id': 5508222591, 'user': 'aikuang时代', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '商塑与浙江省河北企业家见证新型企业！'}, {'id': 4984605857, 'user': '废铁压块设备☎', 'renum': 0, 'is_top': 'False', 'is_good': 'False', 'title': '液压花砖机'}, {'id': 3230625820, 'user': '贴吧用户_QJW9yaV', 'renum': 4, 'is_top': 'False', 'is_good': 'False', 'title': '。'}, {'id': 1, 'user': None, 'renum': 0, 'is_top': 'True', 'is_good': 'False', 'title': '本吧吧主火热招募中，点击参加'}]
#
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
# 插入数据成功
